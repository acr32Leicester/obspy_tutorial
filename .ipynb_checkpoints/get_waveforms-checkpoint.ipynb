# %%
from obspy.clients.fdsn import Client # function to download data from data centre
from obspy import UTCDateTime, read_inventory

# %%
client = Client("RASPISHAKE")

# %%
#t = UTCDateTime(2022, 8, 14, 21, 4, 45)
# t = UTCDateTime(year, month, day, hour, minute, second, microsecond)
# alternatively as a date string t = UTCDateTime("2022/08/15 10:06:37")
t = UTCDateTime("2022-07-27 00:43:28")

# %%
st = client.get_waveforms("AM","RE70F","00","SHZ",t,t + 60 * 60, attach_response=True)
# st = client.get_waveforms("Network","Station ID","","channel",starttime,endtime)
# endtime is set for one hour following the start time

# %%
st.plot()

# %%
pre_filt = (0.005, 0.006, 30.0, 35.0)

st.remove_response(output="VEL", pre_filt=pre_filt)
st.plot()
